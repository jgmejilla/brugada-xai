# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

path = Path.cwd().parent / 'data' / 'lifecare' / '062.npy'
assert path.exists()

signal = np.load(path, allow_pickle=True)

x1, y1 = zip(*signal[0])
plt.plot(x1, y1)

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

path = Path.cwd().parent / 'samples' / 'positive-lifecare' / 'positive_051.npy'
assert path.exists()

signal = np.load(path, allow_pickle=True)
plt.plot(signal[0])
